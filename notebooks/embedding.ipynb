# %% [markdown]
# ### Embedding

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("BAAI/bge-large-en")

emb = model.encode("How does authentication work?",show_progress_bar=True)
# Out:
# Loading weights: 100%|██████████| 391/391 [00:00<00:00, 5670.60it/s]
# BertModel LOAD REPORT from: BAAI/bge-large-en
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.29it/s]

# %%
print(f"Generated embeddings with shape:{emb.shape}")
# Out:
# Generated embeddings with shape:(1024,)
